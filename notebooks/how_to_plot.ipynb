# %% [markdown]
# ## Here are some plotting examples for your perusal

# %%
import pandas as pd

# %matplotlib inline 

import sys 
sys.path.insert(0, "../")
import clustered_stacked_chart # import module

reload(clustered_stacked_chart)
# Out:
# <module 'clustered_stacked_chart' from '../clustered_stacked_chart.py'>

# %% [markdown]
# ### Import data

# %%
electiondata = pd.read_csv("../data/electiondatabygenderbyage.csv")

# %%
electiondata
# Out:
#    Gender    Age  Hillary  Trump  Other
# 0    Male  18-34       51     40      9
# 1    Male  35-49       47     45      8
# 2    Male  50-64       37     57      6
# 3    Male    65+       39     55      6
# 4  Female  18-34       69     25      6
# 5  Female  35-49       55     34     11
# 6  Female  50-64       60     35      5
# 7  Female    65+       52     43      5

# %% [markdown]
# ### Clusters Gender, then stacks by Age

# %%
clustered_stacked_chart.plot(electiondata, 
                             my_two_segments=['Gender','Age'],
                             title = "Election Preferences by Gender and Age")

# %% [markdown]
# ### Clusters Age, then stacks by Gender

# %%
"""
 Other options:
# use a difference stylesheet
# increase width of bars
# don't display the response frequencies

"""

clustered_stacked_chart.plot(electiondata, 
                             my_two_segments=['Age','Gender'],
                             title = "Election Preferences by Age and Gender", 
                             stylesheet= "ggplot", 
                             bar_width=0.9,
                             display_frequencies=False)

# %% [markdown]
# ### Clusters Gender, then stacks by Age

# %%
"""
Other options:
# reorder candidates with "custom_order_values" parameter
# decrease bar color transparency with "alpha" parameter (range of 0 to 1)
# use some patriotic colors
"""
 

clustered_stacked_chart.plot(electiondata, 
                             my_two_segments=['Gender','Age'],
                             title = "Election Preferences by Gender and Age",
                             custom_order_values = ['Trump','Hillary','Other'],
                             colors = ["#FA051F","#387AF5","#FFFFFF"],
                             alpha=1,
                            display_y_axis=False)
